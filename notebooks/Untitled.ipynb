# %%
#import yaoyorozu as yy
from yaoyorozu.utils.geometry import *

atoms = read_xyz("/home/yoshida/calc/20260227_fe-hmti_renewal/cn_2/ccsd_t/s0_opt/orca.xyz")
atoms = read_xyz("/home/yoshida/calc/20260227_fe-hmti_renewal/cn_2/ccsd_t/s0_opt/orca.xyz")

# %%
print(measure_geometry(index=(0,1),mole=atoms))
print(measure_geometry(mole=atoms,index=[51,0,49]))
# Out:
# 1.9299832996458086
# 179.99666590721824

# %%
aaa=[[1,0,0],[0,-12,-1],[0,0,-1]]
atoms=["H","O","H"]

bbb=MOLECULE(atoms=atoms,coord=aaa)

# %%
write_xyz(file_path="./H2O.xyz",mole=bbb)

# %%
! pwd
# Out:
# /home/yoshida/dev/yaoyorozu/notebooks

# %%
! which python
# Out:
# /home/yoshida/dev/yaoyorozu/.venv/bin/python
